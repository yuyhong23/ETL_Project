# %%
# Import dependencies
import pandas as pd
from pyxlsb import open_workbook

# %% [markdown]
# # Extract Data Into DataFrames

# %% [markdown]
# ### Data 1: Irena.org Dataset on Electricity Installed Capacity (MW)

# %%
# Import data file
irena_eic_file = "data/IRENA_Stats_Tool.xlsb"

irena_eic_df = []
with open_workbook (irena_eic_file) as wb:
     with wb.get_sheet("Data") as sheet:
        for row in sheet.rows():
            irena_eic_df.append([item.v for item in row])

irena_eic_df = pd.DataFrame(irena_eic_df[8:], columns=irena_eic_df[5])
irena_eic_df.head()
# Out:
#    Region  Country ISO Code         RE or Non-RE  \
# 0  Africa  Algeria      DZA  Total Non-Renewable
# 1  Africa  Algeria      DZA  Total Non-Renewable
# 2  Africa  Algeria      DZA      Total Renewable
# 3  Africa  Algeria      DZA      Total Renewable
# 4  Africa  Algeria      DZA      Total Renewable
#
#                     Group Technology                Technology Poducer Type  \
# 0                       Fossil fuels              Fossil fuels      On-grid
# 1                       Fossil fuels              Fossil fuels      On-grid
# 2  Hydropower (excl. Pumped Storage)      Renewable hydropower      On-grid
# 3  Hydropower (excl. Pumped Storage)      Renewable hydropower      On-grid
# 4                       Solar energy  Concentrated solar power      On-grid
#
#      Year  Electricity Installed Capacity (MW)        ...               NaN  \
# 0  2018.0                              21308.0  None  ...  None  None  None
# 1  2019.0                              23508.0  None  ...  None  None  None
# 2  2018.0                                228.0  None  ...  None  None  None
# 3  2019.0                                228.0  None  ...  None  None  None
# 4  2018.0                                 25.0  None  ...  None  None  None
#
#     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 21 columns]

# %%
# Get coloumns 
irena_eic_df.columns
# Out:
# Index([                             'Region',
#                                    'Country',
#                                   'ISO Code',
#                               'RE or Non-RE',
#                           'Group Technology',
#                                 'Technology',
#                               'Poducer Type',
#                                       'Year',
#        'Electricity Installed Capacity (MW)',
#                                           '',
#                                           '',
#                                           '',
#                                           '',
#                                         None,
#                                         None,
#                                         None,
#                                         None,
#                                         None,
#                                         None,
#                                         None,
#                                         None],
#       dtype='object')

# %%
# Extract wanted columns
eic_cols = ['Region','Country','Year','RE or Non-RE','Group Technology','Technology','Poducer Type','Electricity Installed Capacity (MW)']
eic_countries = irena_eic_df[eic_cols].copy()
eic_countries.head()
# Out:
#    Region  Country    Year         RE or Non-RE  \
# 0  Africa  Algeria  2018.0  Total Non-Renewable
# 1  Africa  Algeria  2019.0  Total Non-Renewable
# 2  Africa  Algeria  2018.0      Total Renewable
# 3  Africa  Algeria  2019.0      Total Renewable
# 4  Africa  Algeria  2018.0      Total Renewable
#
#                     Group Technology                Technology Poducer Type  \
# 0                       Fossil fuels              Fossil fuels      On-grid
# 1                       Fossil fuels              Fossil fuels      On-grid
# 2  Hydropower (excl. Pumped Storage)      Renewable hydropower      On-grid
# 3  Hydropower (excl. Pumped Storage)      Renewable hydropower      On-grid
# 4                       Solar energy  Concentrated solar power      On-grid
#
#    Electricity Installed Capacity (MW)
# 0                              21308.0
# 1                              23508.0
# 2                                228.0
# 3                                228.0
# 4                                 25.0

# %%
# Drop rows with empty values
eic_countries.dropna()
# Out:
#              Region    Country    Year         RE or Non-RE  \
# 0            Africa    Algeria  2018.0  Total Non-Renewable
# 1            Africa    Algeria  2019.0  Total Non-Renewable
# 2            Africa    Algeria  2018.0      Total Renewable
# 3            Africa    Algeria  2019.0      Total Renewable
# 4            Africa    Algeria  2018.0      Total Renewable
# ...             ...        ...     ...                  ...
# 2968  South America  Venezuela  2019.0      Total Renewable
# 2969  South America  Venezuela  2018.0      Total Renewable
# 2970  South America  Venezuela  2019.0      Total Renewable
# 2971  South America  Venezuela  2018.0      Total Renewable
# 2972  South America  Venezuela  2019.0      Total Renewable
#
#                        Group Technology                   Technology  \
# 0                          Fossil fuels                 Fossil fuels
# 1                          Fossil fuels                 Fossil fuels
# 2     Hydropower (excl. Pumped Storage)         Renewable hydropower
# 3     Hydropower (excl. Pumped Storage)         Renewable hydropower
# 4                          Solar energy     Concentrated solar power
# ...                                 ...                          ...
# 2968                       Solar energy  Off-grid Solar photovoltaic
# 2969                       Solar energy   On-grid Solar photovoltaic
# 2970                       Solar energy   On-grid Solar photovoltaic
# 2971                        Wind energy          Onshore wind energy
# 2972                        Wind energy          Onshore wind energy
#
#      Poducer Type  Electricity Installed Capacity (MW)
# 0         On-grid                             21308.00
# 1         On-grid                             23508.00
# 2         On-grid                               228.00
# 3         On-grid                               228.00
# 4         On-grid                                25.00
# ...           ...                                  ...
# 2968     Off-grid                                 3.00
# 2969      On-grid                                 1.00
# 2970      On-grid                                 2.32
# 2971     Off-grid                                71.28
# 2972     Off-grid                                71.28
#
# [2973 rows x 8 columns]

# %% [markdown]
# #### Extracting data from my selected three countries: China, Germany, and United States

# %%
# Extracting China's data
eic_china = eic_countries[eic_countries["Country"]=="China"]
eic_china.set_index("Region", inplace=True)
eic_china.head()
# Out:
#        Country    Year         RE or Non-RE            Group Technology  \
# Region
# Asia     China  2018.0  Total Non-Renewable                Fossil fuels
# Asia     China  2019.0  Total Non-Renewable                Fossil fuels
# Asia     China  2018.0  Total Non-Renewable                     Nuclear
# Asia     China  2019.0  Total Non-Renewable                     Nuclear
# Asia     China  2018.0  Total Non-Renewable  Other non-renewable energy
#
#                         Technology Poducer Type  \
# Region
# Asia                  Fossil fuels      On-grid
# Asia                  Fossil fuels      On-grid
# Asia                       Nuclear      On-grid
# Asia                       Nuclear      On-grid
# Asia    Other non-renewable energy      On-grid
#
#         Electricity Installed Capacity (MW)
# Region
# Asia                            1126270.000
# Asia                            1168004.147
# Asia                              44660.000
# Asia                              48740.000
# Asia                               4575.000

# %%
# Extracting Germany's data
eic_germany = eic_countries[eic_countries["Country"]=="Germany"]
eic_germany.set_index("Region", inplace=True)
eic_germany.head()
# Out:
#         Country    Year         RE or Non-RE            Group Technology  \
# Region
# Europe  Germany  2018.0  Total Non-Renewable                Fossil fuels
# Europe  Germany  2019.0  Total Non-Renewable                Fossil fuels
# Europe  Germany  2018.0  Total Non-Renewable                     Nuclear
# Europe  Germany  2019.0  Total Non-Renewable                     Nuclear
# Europe  Germany  2018.0  Total Non-Renewable  Other non-renewable energy
#
#                         Technology Poducer Type  \
# Region
# Europe                Fossil fuels      On-grid
# Europe                Fossil fuels      On-grid
# Europe                     Nuclear      On-grid
# Europe                     Nuclear      On-grid
# Europe  Other non-renewable energy      On-grid
#
#         Electricity Installed Capacity (MW)
# Region
# Europe                              91415.0
# Europe                              91991.0
# Europe                              10799.0
# Europe                              10799.0
# Europe                               2332.0

# %%
# Extracting USA's data
eic_usa = eic_countries[eic_countries["Country"]=="United States"]
eic_usa.set_index("Region", inplace=True)
eic_usa.head()
# Out:
#                      Country    Year         RE or Non-RE  \
# Region
# North America  United States  2018.0  Total Non-Renewable
# North America  United States  2019.0  Total Non-Renewable
# North America  United States  2018.0  Total Non-Renewable
# North America  United States  2019.0  Total Non-Renewable
# North America  United States  2018.0  Total Non-Renewable
#
#                          Group Technology                  Technology  \
# Region
# North America                Fossil fuels                Fossil fuels
# North America                Fossil fuels                Fossil fuels
# North America                     Nuclear                     Nuclear
# North America                     Nuclear                     Nuclear
# North America  Other non-renewable energy  Other non-renewable energy
#
#               Poducer Type  Electricity Installed Capacity (MW)
# Region
# North America      On-grid                             750619.0
# North America      On-grid                             743307.0
# North America      On-grid                              99629.0
# North America      On-grid                              98266.3
# North America      On-grid                               3292.5
